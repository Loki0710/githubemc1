# %% [markdown]
# <a href="https://colab.research.google.com/github/Loki0710/githubemc1/blob/main/De_novo_drug_design_GNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparing the environment
#
# We first need to install all the libraries and modules we will be using for generating molecules using GraphINVENT

# %%
################## Installing Conda #####################

# %env PYTHONPATH=
! rm -rf Miniconda3-py38_23.1.0-1-Linux-x86_64.sh.* # In case this is run multiple times
! wget https://repo.anaconda.com/miniconda/Miniconda3-py38_23.1.0-1-Linux-x86_64.sh
# ! wget https://repo.anaconda.com/archive/Anaconda3-2022.10-Linux-x86_64.sh
! chmod +x Miniconda3-py38_23.1.0-1-Linux-x86_64.sh
! bash ./Miniconda3-py38_23.1.0-1-Linux-x86_64.sh -b -f -p /usr/local

! conda install --channel defaults conda python=3.8 --yes
! conda update --channel defaults --all --yes

import sys
sys.path.append('/usr/local/lib/python3.8/site-packages/')

! conda init bash

################ Cloning GraphINVENT ####################

! rm -rf ./GraphINVENT # In case this is run multiple times
! git clone https://github.com/literalEval/GraphINVENT.git
# %cd GraphINVENT
! ls

################ Activating our environment #############

! conda env create -f environments/graphinvent.yml
! source ~/.bashrc
! source activate graphinvent
! eval "$(conda shell.bash hook)"
! source ~/.bashrc
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.8/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# Cloning into 'GraphINVENT'...
# remote: Enumerating objects: 532, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 532 (delta 3), reused 10 (delta 3), pack-reused 522 (from 1)
# Receiving objects: 100% (532/532), 22.25 MiB | 21.04 MiB/s, done.
# Resolving deltas: 100% (301/301), done.
# /content/GraphINVENT
# cover-image.png  GNN.ipynb    output		     submit-pre-training.py		tutorials
# data		 graphinvent  README.md		     submit-pre-training-supercloud.py
# environments	 LICENSE      submit-fine-tuning.py  tools
# \ WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 24.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.11.1
#
#
#
# Downloading and Extracting Packages
# astroid-2.4.2        | 297 KB    | :   0% 0/1 [00:00<?, ?it/s]
# torchvision-0.9.0    | 25.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# _openmp_mutex-4.5    | 22 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# openh264-2.1.0       | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# lz4-c-1.9.3          | 216 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libgfortran5-9.3.0   | 2.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pixman-0.38.0        | 594 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libcurl-7.75.0       | 328 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# tornado-6.1          | 649 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# tensorboard-1.15.0   | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# freetype-2.10.4      | 901 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.0.1         | 206 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.67.4          | 3.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.9.0        | 225 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.3.0    | 62 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-xextproto-7.3.0 | 28 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.11           | 419 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# torchvision-0.9.0    | 25.7 MB   | :   3% 0.032843347504857255/1 [00:00<00:03,  3.11s/it]
#
#
# openh264-2.1.0       | 1.5 MB    | :  11% 0.11461335544741588/1 [00:00<00:00,  1.12it/s]
#
#
#
# lz4-c-1.9.3          | 216 KB    | :  52% 0.5181717962156398/1 [00:00<00:00,  5.02it/s]
#
#
#
#
# libgfortran5-9.3.0   | 2.0 MB    | :   1% 0.00799698941462955/1 [00:00<00:13, 13.60s/it]
#
#
#
#
#
# pixman-0.38.0        | 594 KB    | :   3% 0.026957477475105796/1 [00:00<00:04,  5.02s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :   0% 0.00026830440215240266/1 [00:00<09:53, 593.85s/it]
# torchvision-0.9.0    | 25.7 MB   | :   9% 0.09427257154171989/1 [00:00<00:01,  2.06s/it]
#
#
#
#
# libgfortran5-9.3.0   | 2.0 MB    | :  53% 0.5278013013655504/1 [00:00<00:00,  2.97it/s]
#
#
#
#
#
#
#
# libcurl-7.75.0       | 328 KB    | :   5% 0.048822787940914415/1 [00:00<00:04,  4.56s/it]
#
#
#
#
#
#
#
#
# tornado-6.1          | 649 KB    | :   2% 0.024640447089362225/1 [00:00<00:09,  9.71s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :   3% 0.028976875432459484/1 [00:00<00:07,  7.45s/it]
#
# _openmp_mutex-4.5    | 22 KB     | : 100% 1.0/1 [00:00<00:00,  3.58it/s]
#
# _openmp_mutex-4.5    | 22 KB     | : 100% 1.0/1 [00:00<00:00,  3.58it/s]
#
#
#
#
#
#
#
#
#
# tensorboard-1.15.0   | 3.8 MB    | :   0% 0.00412770282152069/1 [00:00<01:09, 70.17s/it]
# torchvision-0.9.0    | 25.7 MB   | :  14% 0.14292938266002694/1 [00:00<00:01,  2.13s/it]
#
#
#
#
#
#
#
#
#
#
# freetype-2.10.4      | 901 KB    | :   2% 0.01776490130851336/1 [00:00<00:16, 17.12s/it]
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.0.1         | 206 KB    | :   8% 0.07748330590394037/1 [00:00<00:03,  4.18s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :   5% 0.05419748923478533/1 [00:00<00:05,  5.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.67.4          | 3.6 MB    | :   0% 0.004399644784538514/1 [00:00<01:24, 85.00s/it]
#
#
#
#
#
#
#
#
#
# tensorboard-1.15.0   | 3.8 MB    | :  31% 0.30545000879253104/1 [00:00<00:00,  1.01s/it]
# torchvision-0.9.0    | 25.7 MB   | :  19% 0.19036977350037632/1 [00:00<00:01,  2.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.9.0        | 225 KB    | :   7% 0.07115372923018128/1 [00:00<00:05,  5.54s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :   8% 0.0815645382543304/1 [00:00<00:04,  4.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.3.0    | 62 KB     | :  26% 0.25760601248408044/1 [00:00<00:01,  1.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.67.4          | 3.6 MB    | :  35% 0.3519715827630811/1 [00:00<00:00,  1.04s/it]
#
#
#
#
#
#
#
#
#
# tensorboard-1.15.0   | 3.8 MB    | :  68% 0.6769432627293931/1 [00:00<00:00,  1.85it/s]
# torchvision-0.9.0    | 25.7 MB   | :  24% 0.24389226573051406/1 [00:00<00:01,  2.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-xextproto-7.3.0 | 28 KB     | :  58% 0.5799440727761849/1 [00:00<00:00,  1.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.11           | 419 KB    | :   4% 0.038175480455570676/1 [00:00<00:13, 14.45s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  11% 0.11080971808894229/1 [00:00<00:03,  4.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.67.4          | 3.6 MB    | :  76% 0.7567389029406244/1 [00:00<00:00,  1.83it/s]
# torchvision-0.9.0    | 25.7 MB   | :  31% 0.31079538101818627/1 [00:00<00:01,  1.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   0% 7.304393413416603e-05/1 [00:00<2:23:12, 8593.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# lz4-c-1.9.3          | 216 KB    | : 100% 1.0/1 [00:00<00:00,  5.02it/s]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  14% 0.13549372308696334/1 [00:00<00:03,  4.29s/it]
# torchvision-0.9.0    | 25.7 MB   | :  37% 0.3661425036652605/1 [00:00<00:01,  1.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   1% 0.0070852616110141054/1 [00:00<01:17, 78.42s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  16% 0.15964111928067956/1 [00:00<00:03,  4.64s/it]
# torchvision-0.9.0    | 25.7 MB   | :  43% 0.4251388871462078/1 [00:00<00:01,  1.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   1% 0.014243567156162377/1 [00:00<00:39, 40.45s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  18% 0.181910384659329/1 [00:00<00:03,  4.67s/it]
# torchvision-0.9.0    | 25.7 MB   | :  48% 0.48048600979328204/1 [00:00<00:00,  1.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   2% 0.02045230155756649/1 [00:00<00:29, 30.17s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  21% 0.20820421607026443/1 [00:01<00:03,  4.39s/it]
# torchvision-0.9.0    | 25.7 MB   | :  55% 0.5467809149419754/1 [00:01<00:00,  1.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   3% 0.026222772354165605/1 [00:01<00:24, 25.59s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  23% 0.2328882210682855/1 [00:01<00:03,  4.29s/it]
# torchvision-0.9.0    | 25.7 MB   | :  61% 0.6076019288398592/1 [00:01<00:00,  1.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# astroid-2.4.2        | 297 KB    | : 100% 1.0/1 [00:01<00:00,  1.19s/it]
#
#
#
#
#
# pixman-0.38.0        | 594 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
# pixman-0.38.0        | 594 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  26% 0.25676731285984933/1 [00:01<00:03,  4.27s/it]
# torchvision-0.9.0    | 25.7 MB   | :  67% 0.6659901021818276/1 [00:01<00:00,  1.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   4% 0.040028075905522986/1 [00:01<00:18, 19.20s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  29% 0.29352501595472846/1 [00:01<00:02,  3.71s/it]
# torchvision-0.9.0    | 25.7 MB   | :  72% 0.7225536451068596/1 [00:01<00:00,  1.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   5% 0.04704029358240292/1 [00:01<00:17, 17.91s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  32% 0.32142867377857837/1 [00:01<00:02,  3.70s/it]
# torchvision-0.9.0    | 25.7 MB   | :  78% 0.7815500285878069/1 [00:01<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   6% 0.05544034600783202/1 [00:01<00:14, 15.78s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  35% 0.34879572279812343/1 [00:01<00:02,  3.97s/it]
# torchvision-0.9.0    | 25.7 MB   | :  84% 0.8399382019297753/1 [00:01<00:00,  1.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   6% 0.06237951975057779/1 [00:01<00:16, 17.47s/it]
#
#
#
#
#
#
#
# libcurl-7.75.0       | 328 KB    | : 100% 1.0/1 [00:01<00:00,  1.64s/it]
#
#
#
#
#
#
#
# libcurl-7.75.0       | 328 KB    | : 100% 1.0/1 [00:01<00:00,  1.64s/it]
# torchvision-0.9.0    | 25.7 MB   | :  89% 0.894068904298892/1 [00:01<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   7% 0.06888042988851857/1 [00:01<00:16, 17.41s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  37% 0.3745529454047541/1 [00:01<00:03,  4.91s/it]
# torchvision-0.9.0    | 25.7 MB   | :  95% 0.9524570776408604/1 [00:01<00:00,  1.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   8% 0.07508916428992268/1 [00:01<00:15, 17.14s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  40% 0.3984320371963179/1 [00:01<00:02,  4.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   8% 0.08283182130814427/1 [00:01<00:14, 15.84s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  42% 0.4225794333900341/1 [00:01<00:02,  4.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :   9% 0.08940577538021922/1 [00:02<00:14, 16.14s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  45% 0.4483366559966648/1 [00:02<00:02,  4.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  10% 0.096344949122965/1 [00:02<00:14, 15.90s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  48% 0.4802648798528007/1 [00:02<00:02,  4.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  10% 0.10335716679984494/1 [00:02<00:13, 15.41s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  51% 0.5052171892529742/1 [00:02<00:02,  4.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  11% 0.11000416480605404/1 [00:02<00:14, 16.17s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  53% 0.5285596722402331/1 [00:02<00:02,  4.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  12% 0.11628594314159232/1 [00:02<00:14, 16.56s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  55% 0.5508289376188826/1 [00:02<00:02,  5.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  12% 0.12242163360886227/1 [00:02<00:15, 17.69s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  58% 0.5776593778341229/1 [00:02<00:02,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  13% 0.1281921044054614/1 [00:02<00:15, 17.71s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  61% 0.6082460796794967/1 [00:02<00:01,  4.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  13% 0.1339625752020605/1 [00:02<00:15, 17.88s/it]
#
#
# openh264-2.1.0       | 1.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.92s/it]
#
#
# openh264-2.1.0       | 1.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.92s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  64% 0.635076519894737/1 [00:02<00:01,  4.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  14% 0.14119392468134295/1 [00:02<00:14, 16.59s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  67% 0.6678096569573302/1 [00:03<00:01,  3.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  15% 0.1481330984240887/1 [00:03<00:13, 15.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  15% 0.15485314036443198/1 [00:03<00:13, 15.67s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  69% 0.694371792770418/1 [00:03<00:01,  3.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  16% 0.1615001383706411/1 [00:03<00:13, 15.53s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  72% 0.7206656241813535/1 [00:03<00:01,  3.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  17% 0.1690236635864602/1 [00:03<00:12, 14.85s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  75% 0.7464228467879841/1 [00:03<00:01,  4.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  18% 0.17640110093401096/1 [00:03<00:12, 14.60s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  77% 0.772984982601072/1 [00:03<00:00,  4.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  18% 0.18348636254502507/1 [00:03<00:11, 14.59s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  80% 0.8014252492292266/1 [00:03<00:00,  4.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  19% 0.1903524923536367/1 [00:03<00:13, 16.12s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  83% 0.8263775586294001/1 [00:03<00:00,  4.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  20% 0.19670731462330912/1 [00:03<00:13, 17.38s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  85% 0.8497200416166591/1 [00:03<00:00,  4.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  20% 0.20335431262951822/1 [00:03<00:13, 16.86s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  87% 0.8722576113974609/1 [00:03<00:00,  4.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  21% 0.20941695916265402/1 [00:04<00:14, 17.96s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  89% 0.894258572373958/1 [00:04<00:00,  4.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  22% 0.21511438602511895/1 [00:04<00:14, 17.96s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  92% 0.9173327509590646/1 [00:04<00:00,  4.68s/it]
#
#
#
#
# libgfortran5-9.3.0   | 2.0 MB    | : 100% 1.0/1 [00:04<00:00,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  22% 0.2211039886241206/1 [00:04<00:14, 18.31s/it]
#
#
#
#
# libgfortran5-9.3.0   | 2.0 MB    | : 100% 1.0/1 [00:04<00:00,  4.94s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  94% 0.9390654075334092/1 [00:04<00:00,  4.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  23% 0.22753185482792718/1 [00:04<00:13, 17.64s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  96% 0.960261455303449/1 [00:04<00:00,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  23% 0.2333023256245263/1 [00:04<00:13, 17.80s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | :  99% 0.9860186779100797/1 [00:04<00:00,  4.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  24% 0.23929192822352793/1 [00:04<00:13, 17.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  25% 0.24528153082252954/1 [00:04<00:13, 17.36s/it]
#
#
#
#
#
#
#
#
# tornado-6.1          | 649 KB    | : 100% 1.0/1 [00:04<00:00,  4.62s/it]
#
#
#
#
#
#
#
#
# tornado-6.1          | 649 KB    | : 100% 1.0/1 [00:04<00:00,  4.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  25% 0.25134417735566533/1 [00:04<00:12, 17.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  26% 0.2578450874936061/1 [00:04<00:12, 16.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  26% 0.26434599763154687/1 [00:04<00:12, 16.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  27% 0.27048168809881684/1 [00:05<00:13, 18.19s/it]
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.0.1         | 206 KB    | : 100% 1.0/1 [00:05<00:00,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.0.1         | 206 KB    | : 100% 1.0/1 [00:05<00:00,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  28% 0.2795391359314534/1 [00:05<00:11, 15.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  29% 0.28625917787179667/1 [00:05<00:10, 15.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  29% 0.29319835161454244/1 [00:05<00:11, 15.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  30% 0.29969926175248324/1 [00:05<00:11, 16.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  31% 0.30671147942936317/1 [00:05<00:11, 16.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  31% 0.3130663016990356/1 [00:05<00:11, 16.11s/it]
#
#
#
#
#
#
#
#
#
#
# freetype-2.10.4      | 901 KB    | : 100% 1.0/1 [00:05<00:00,  5.76s/it]
#
#
#
#
#
#
#
#
#
#
# freetype-2.10.4      | 901 KB    | : 100% 1.0/1 [00:05<00:00,  5.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  32% 0.3193480800345739/1 [00:05<00:11, 16.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.3.0    | 62 KB     | : 100% 1.0/1 [00:05<00:00,  6.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  33% 0.325556814435978/1 [00:05<00:11, 17.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.3.0    | 62 KB     | : 100% 1.0/1 [00:05<00:00,  6.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  33% 0.33147337310084546/1 [00:06<00:11, 17.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.9.0        | 225 KB    | : 100% 1.0/1 [00:06<00:00,  6.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.9.0        | 225 KB    | : 100% 1.0/1 [00:06<00:00,  6.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  34% 0.33724384389744455/1 [00:06<00:11, 17.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-xextproto-7.3.0 | 28 KB     | : 100% 1.0/1 [00:06<00:00,  7.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-xextproto-7.3.0 | 28 KB     | : 100% 1.0/1 [00:06<00:00,  7.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  34% 0.3430143146940437/1 [00:06<00:12, 18.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  35% 0.3486386976223745/1 [00:06<00:11, 18.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  35% 0.3541900366165711/1 [00:06<00:12, 19.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  36% 0.36091007855691437/1 [00:06<00:11, 17.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.11           | 419 KB    | : 100% 1.0/1 [00:06<00:00,  6.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.11           | 419 KB    | : 100% 1.0/1 [00:06<00:00,  6.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  37% 0.3681414280361968/1 [00:06<00:10, 16.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  38% 0.3752266896472109/1 [00:06<00:10, 16.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  38% 0.3815084679827492/1 [00:06<00:10, 16.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  39% 0.38947025680337327/1 [00:07<00:09, 15.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  40% 0.3967016062826557/1 [00:07<00:09, 15.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  40% 0.40393295576193816/1 [00:07<00:08, 15.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  41% 0.4106529977022814/1 [00:07<00:08, 15.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  42% 0.4172999957084905/1 [00:07<00:09, 17.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  42% 0.42328959830749213/1 [00:07<00:10, 18.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  43% 0.4295713766430304/1 [00:07<00:10, 17.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  44% 0.436875770056447/1 [00:07<00:09, 16.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  45% 0.44549495428427865/1 [00:07<00:08, 14.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  45% 0.45345674310490275/1 [00:08<00:07, 14.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  46% 0.4604689607817827/1 [00:08<00:07, 14.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  47% 0.4677003102610651/1 [00:08<00:07, 14.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  48% 0.47515079154275003/1 [00:08<00:07, 14.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  48% 0.4847195469143258/1 [00:08<00:06, 12.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  49% 0.49253524786668157/1 [00:08<00:06, 13.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  50% 0.5001318170166348/1 [00:08<00:07, 14.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  51% 0.5070709907593806/1 [00:08<00:07, 15.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  51% 0.5140101645021263/1 [00:08<00:07, 15.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  52% 0.5213145579155429/1 [00:09<00:07, 15.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  53% 0.5278885119876179/1 [00:09<00:07, 15.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  53% 0.5347546417962296/1 [00:09<00:07, 15.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  54% 0.5420590352096462/1 [00:09<00:07, 15.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  55% 0.5486329892817211/1 [00:09<00:07, 15.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  56% 0.5558643387610035/1 [00:09<00:07, 16.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  56% 0.5619269852941393/1 [00:09<00:07, 16.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  57% 0.5679165878931409/1 [00:09<00:07, 17.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  57% 0.5739061904921425/1 [00:10<00:08, 20.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  58% 0.5790923098156683/1 [00:10<00:12, 29.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  59% 0.5858123517560115/1 [00:10<00:10, 25.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  59% 0.5906332514088666/1 [00:10<00:10, 26.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  60% 0.5950889313910507/1 [00:10<00:10, 26.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  60% 0.5992524356366982/1 [00:10<00:10, 26.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  60% 0.6033428959482114/1 [00:10<00:10, 27.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  61% 0.6090403228106763/1 [00:11<00:09, 24.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  61% 0.614591661804873/1 [00:11<00:08, 22.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  62% 0.6218230112841554/1 [00:11<00:07, 19.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  63% 0.6273013063442179/1 [00:11<00:07, 20.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  63% 0.6323413377994753/1 [00:11<00:10, 27.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  64% 0.6379657207278061/1 [00:11<00:08, 24.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  64% 0.6438822793926736/1 [00:11<00:07, 22.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  65% 0.6489223108479311/1 [00:11<00:07, 21.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  66% 0.6560075724589451/1 [00:11<00:06, 19.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  66% 0.6625815265310201/1 [00:12<00:06, 18.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  67% 0.6685711291300217/1 [00:12<00:05, 17.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  68% 0.6750720392679624/1 [00:12<00:05, 17.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  68% 0.6814999054717691/1 [00:12<00:05, 17.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  69% 0.6881469034779781/1 [00:12<00:05, 17.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  70% 0.6950860772207239/1 [00:12<00:05, 17.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  70% 0.7010026358855914/1 [00:12<00:05, 17.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  71% 0.710498347323033/1 [00:12<00:04, 14.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  72% 0.7184601361436571/1 [00:12<00:03, 14.14s/it]
#
#
#
#
#
#
#
#
#
# tensorboard-1.15.0   | 3.8 MB    | : 100% 1.0/1 [00:13<00:00, 17.41s/it]
#
#
#
#
#
#
#
#
#
# tensorboard-1.15.0   | 3.8 MB    | : 100% 1.0/1 [00:13<00:00, 17.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  73% 0.725910617425342/1 [00:13<00:03, 14.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  73% 0.7343106698507711/1 [00:13<00:03, 13.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  74% 0.7419072390007244/1 [00:13<00:03, 13.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  75% 0.7495038081506776/1 [00:13<00:03, 13.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  76% 0.757100377300631/1 [00:13<00:03, 13.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  76% 0.7646969464505842/1 [00:13<00:03, 14.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  77% 0.7717822080615983/1 [00:13<00:03, 15.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  78% 0.7785752939360757/1 [00:13<00:03, 16.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  78% 0.7849301162057482/1 [00:13<00:03, 16.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  79% 0.7920153778167622/1 [00:14<00:03, 15.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  80% 0.7984432440205689/1 [00:14<00:03, 16.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  81% 0.8061859010387905/1 [00:14<00:02, 15.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  81% 0.8134902944522071/1 [00:14<00:02, 14.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  82% 0.8210138196680262/1 [00:14<00:02, 14.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.67.4          | 3.6 MB    | : 100% 1.0/1 [00:14<00:00,  1.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  83% 0.8278069055425037/1 [00:14<00:02, 15.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  83% 0.8348191232193836/1 [00:14<00:02, 14.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  84% 0.8427809120400077/1 [00:14<00:02, 14.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  85% 0.8519844477409126/1 [00:14<00:01, 13.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  86% 0.8596540608250001/1 [00:15<00:02, 14.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  87% 0.8670314981725508/1 [00:15<00:01, 14.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  88% 0.875066330927309/1 [00:15<00:01, 13.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  88% 0.8823707243407256/1 [00:15<00:01, 14.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  89% 0.8896020738200081/1 [00:15<00:01, 15.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  90% 0.8963951596944856/1 [00:15<00:01, 15.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  90% 0.9031152016348288/1 [00:15<00:01, 15.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  91% 0.9097621996410379/1 [00:15<00:01, 15.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  92% 0.916409197647247/1 [00:15<00:01, 15.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  92% 0.9230561956534561/1 [00:15<00:01, 15.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  93% 0.9294110179231286/1 [00:16<00:01, 15.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  94% 0.9360580159293377/1 [00:16<00:01, 16.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  94% 0.942339794264876/1 [00:16<00:01, 18.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  95% 0.9479641771932068/1 [00:16<00:01, 21.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  95% 0.954245955528745/1 [00:16<00:00, 20.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  96% 0.959505118786405/1 [00:16<00:00, 20.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  97% 0.9666634243315533/1 [00:16<00:00, 18.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  97% 0.9721417193916158/1 [00:16<00:00, 19.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  98% 0.9774739265834098/1 [00:17<00:00, 19.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  98% 0.9848513639309606/1 [00:17<00:00, 18.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | :  99% 0.9908409665299622/1 [00:17<00:00, 18.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | : 100% 0.9994601507577938/1 [00:17<00:00, 15.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# torchvision-0.9.0    | 25.7 MB   | : 100% 1.0/1 [00:41<00:00,  1.97s/it]
#
#
#
#
#
#
# python-3.8.8         | 58.2 MB   | : 100% 1.0/1 [01:04<00:00,  4.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2020.2           | 213.9 MB  | : 100% 1.0/1 [02:32<00:00, 15.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate graphinvent
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# %%bash
# pwd
# source activate graphinvent
# conda install ipykernel -y
# Out:
# /content/GraphINVENT
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/graphinvent
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     comm-0.2.1                 |   py38h06a4308_0          14 KB
#     debugpy-1.5.1              |   py38h295c915_0         1.7 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     entrypoints-0.4            |   py38h06a4308_0          16 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     ipykernel-6.19.2           |   py38hb070fc8_0         218 KB
#     ipython-8.12.2             |   py38h06a4308_0         1.1 MB
#     jedi-0.19.1                |   py38h06a4308_0         1.0 MB
#     jupyter_client-7.1.2       |     pyhd3eb1b0_0          93 KB
#     jupyter_core-5.7.2         |   py38h06a4308_0          80 KB
#     libsodium-1.0.18           |       h7b6447c_0         244 KB
#     matplotlib-inline-0.1.6    |   py38h06a4308_0          16 KB
#     nest-asyncio-1.6.0         |   py38h06a4308_0          14 KB
#     packaging-24.1             |   py38h06a4308_0         147 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     platformdirs-3.10.0        |   py38h06a4308_0          33 KB
#     prompt-toolkit-3.0.43      |   py38h06a4308_0         571 KB
#     psutil-5.8.0               |   py38h27cfd23_1         327 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     pygments-2.15.1            |   py38h06a4308_1         1.8 MB
#     pyzmq-22.3.0               |   py38h295c915_2         476 KB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     traitlets-5.14.3           |   py38h06a4308_0         179 KB
#     wcwidth-0.2.5              |     pyhd3eb1b0_0          26 KB
#     zeromq-4.3.4               |       h2531618_0         331 KB
#     ------------------------------------------------------------
#                                            Total:         8.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   backcall           pkgs/main/noarch::backcall-0.2.0-pyhd3eb1b0_0
#   comm               pkgs/main/linux-64::comm-0.2.1-py38h06a4308_0
#   debugpy            pkgs/main/linux-64::debugpy-1.5.1-py38h295c915_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   entrypoints        pkgs/main/linux-64::entrypoints-0.4-py38h06a4308_0
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   ipykernel          pkgs/main/linux-64::ipykernel-6.19.2-py38hb070fc8_0
#   ipython            pkgs/main/linux-64::ipython-8.12.2-py38h06a4308_0
#   jedi               pkgs/main/linux-64::jedi-0.19.1-py38h06a4308_0
#   jupyter_client     pkgs/main/noarch::jupyter_client-7.1.2-pyhd3eb1b0_0
#   jupyter_core       pkgs/main/linux-64::jupyter_core-5.7.2-py38h06a4308_0
#   libsodium          pkgs/main/linux-64::libsodium-1.0.18-h7b6447c_0
#   matplotlib-inline  pkgs/main/linux-64::matplotlib-inline-0.1.6-py38h06a4308_0
#   nest-asyncio       pkgs/main/linux-64::nest-asyncio-1.6.0-py38h06a4308_0
#   packaging          pkgs/main/linux-64::packaging-24.1-py38h06a4308_0
#   parso              pkgs/main/noarch::parso-0.8.3-pyhd3eb1b0_0
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   platformdirs       pkgs/main/linux-64::platformdirs-3.10.0-py38h06a4308_0
#   prompt-toolkit     pkgs/main/linux-64::prompt-toolkit-3.0.43-py38h06a4308_0
#   psutil             pkgs/main/linux-64::psutil-5.8.0-py38h27cfd23_1
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pygments           pkgs/main/linux-64::pygments-2.15.1-py38h06a4308_1
#   pyzmq              pkgs/main/linux-64::pyzmq-22.3.0-py38h295c915_2
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   traitlets          pkgs/main/linux-64::traitlets-5.14.3-py38h06a4308_0
#   wcwidth            pkgs/main/noarch::wcwidth-0.2.5-pyhd3eb1b0_0
#   zeromq             pkgs/main/linux-64::zeromq-4.3.4-h2531618_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2020.10.14-0 --> pkgs/main::ca-certificates-2024.11.26-h06a4308_0
#   certifi                anaconda::certifi-2020.6.20-py38_0 --> pkgs/main::certifi-2024.8.30-py38h06a4308_0
#   openssl            conda-forge::openssl-1.1.1k-h7f98852_0 --> pkgs/main::openssl-1.1.1w-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# debugpy-1.5.1        | 1.7 MB    |            |   0%
# backcall-0.2.0       | 13 KB     |            |   0%
#
# executing-0.8.3      | 18 KB     |            |   0%
#
#
# nest-asyncio-1.6.0   | 14 KB     |            |   0%
#
#
#
# wcwidth-0.2.5        | 26 KB     |            |   0%
#
#
#
#
# jupyter_core-5.7.2   | 80 KB     |            |   0%
#
#
#
#
#
# decorator-5.1.1      | 12 KB     |            |   0%
#
#
#
#
#
#
# ipython-8.12.2       | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
# ipykernel-6.19.2     | 218 KB    |            |   0%
#
#
#
#
#
#
#
#
# ptyprocess-0.7.0     | 17 KB     |            |   0%
#
#
#
#
#
#
#
#
#
# stack_data-0.2.0     | 22 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# pure_eval-0.2.2      | 14 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-2.0.5      | 20 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.4         | 331 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-inline-0. | 16 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jedi-0.19.1          | 1.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# debugpy-1.5.1        | 1.7 MB    | ###2       |  33%
#
#
#
#
#
#
# ipython-8.12.2       | 1.1 MB    | ##         |  20%
#
#
#
#
#
#
#
#
#
# stack_data-0.2.0     | 22 KB     | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-2.0.5      | 20 KB     | #######8   |  78%
# backcall-0.2.0       | 13 KB     | ########## | 100%
# backcall-0.2.0       | 13 KB     | ########## | 100%
#
# executing-0.8.3      | 18 KB     | ########## | 100%
#
# executing-0.8.3      | 18 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-inline-0. | 16 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.4         | 331 KB    | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jedi-0.19.1          | 1.0 MB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# nest-asyncio-1.6.0   | 14 KB     | ########## | 100%
#
#
# nest-asyncio-1.6.0   | 14 KB     | ########## | 100%
#
#
#
# wcwidth-0.2.5        | 26 KB     | ########## | 100%
#
#
#
# wcwidth-0.2.5        | 26 KB     | ########## | 100%
#
#
#
#
#
# decorator-5.1.1      | 12 KB     | ########## | 100%
#
#
#
#
#
# decorator-5.1.1      | 12 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# ptyprocess-0.7.0     | 17 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# ptyprocess-0.7.0     | 17 KB     | ########## | 100%
#
#
#
#
# jupyter_core-5.7.2   | 80 KB     | ########## | 100%
#
#
#
#
# jupyter_core-5.7.2   | 80 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# stack_data-0.2.0     | 22 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
#
#
#
#
#
#
# ipykernel-6.19.2     | 218 KB    | ########## | 100%
#
#
#
#
#
#
#
# ipykernel-6.19.2     | 218 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# asttokens-2.0.5      | 20 KB     | ########## | 100%
#
#
#
#
#
#
# ipython-8.12.2       | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
# ipython-8.12.2       | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-inline-0. | 16 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# debugpy-1.5.1        | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.4         | 331 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.4         | 331 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jedi-0.19.1          | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jedi-0.19.1          | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 24.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.11.1

# %% [markdown]
# # Preparing a new dataset
# Once you have selected a dataset to study, you must prepare it so that it agrees with the format expected by the program. GraphINVENT expects, for each dataset, three splits in SMILES format. Each split should be named as follows:
#
# - train.smi
# - test.smi
# - valid.smi
#
# These should contain the training set, test set, and validation set, respectively. It is not important for the SMILES to be canonical, and it also does not matter if the file has a header or not. How many structures you put in each split is also up to you (generally the training set is larger than the testing and validation set).

# %%
# %%bash
# pwd
# source activate graphinvent
#
# python3.8
# """
# Example submission script for a GraphINVENT training job (distribution-
# based training, not fine-tuning/optimization job). This can be used to
# pre-train a model before a fine-tuning (via reinforcement learning) job.
#
# To run, type:
# (graphinvent) ~/GraphINVENT$ python submit-pre-training.py
# """
# # load general packages and functions
# import csv
# import sys
# import os
# from pathlib import Path
# import subprocess
# import time
# import torch
# import matplotlib.pyplot as plt
#
#
# # define what you want to do for the specified job(s)
# DATASET          = "gdb13_1K-debug"    # dataset name in "./data/pre-training/"
# JOB_TYPE         = "train"             # "preprocess", "train", "generate", or "test"
# JOBDIR_START_IDX = 0                   # where to start indexing job dirs
# N_JOBS           = 1                   # number of jobs to run per model
# RESTART          = False               # whether or not this is a restart job
# FORCE_OVERWRITE  = True                # overwrite job directories which already exist
# JOBNAME          = "example-job-name"  # used to create a sub directory
#
# # if running using SLURM sbatch, specify params below
# USE_SLURM = False                        # use SLURM or not
# RUN_TIME  = "1-00:00:00"                 # hh:mm:ss
# MEM_GB    = 20                           # required RAM in GB
#
# # for SLURM jobs, set partition to run job on (preprocessing jobs run entirely on
# # CPU, so no need to request GPU partition; all other job types benefit from running
# # on a GPU)
# if JOB_TYPE == "preprocess":
#     PARTITION     = "core"
#     CPUS_PER_TASK = 1
# else:
#     PARTITION     = "gpu"
#     CPUS_PER_TASK = 4
#
# # set paths here
# HOME             = str(Path.home())
# PYTHON_PATH      = "/usr/local/envs/graphinvent/bin/python3.8"
# GRAPHINVENT_PATH = "./graphinvent/"
# DATA_PATH        = "./data/pre-training/"
#
# if torch.cuda.is_available():
#     DEVICE = "cuda"
# else:
#     DEVICE = "cpu"
#
# # define dataset-specific parameters
# params = {
#     "atom_types"   : ["C", "N", "O", "S", "Cl"],
#     "formal_charge": [-1, 0, +1],
#     "max_n_nodes"  : 13,
#     "job_type"     : JOB_TYPE,
#     "dataset_dir"  : f"{DATA_PATH}{DATASET}/",
#     "restart"      : RESTART,
#     "model"        : "GGNN",
#     "sample_every" : 2,
#     "init_lr"      : 1e-4,
#     "epochs"       : 100,
#     "batch_size"   : 50,
#     "block_size"   : 1000,
#     "device"       : DEVICE,
#     "n_samples"    : 100,
#     # additional paramaters can be defined here, if different from the "defaults"
#     # for instance, for "generate" jobs, don't forget to specify "generation_epoch"
#     # and "n_samples"
# }
#
#
# def submit() -> None:
#     """
#     Creates and submits submission script. Uses global variables defined at top
#     of this file.
#     """
#     check_paths()
#
#     # create an output directory
#     dataset_output_path = f"{HOME}/GraphINVENT/output_{DATASET}"
#     tensorboard_path    = os.path.join(dataset_output_path, "tensorboard")
#     if JOBNAME != "":
#         dataset_output_path = os.path.join(dataset_output_path, JOBNAME)
#         tensorboard_path    = os.path.join(tensorboard_path, JOBNAME)
#
#     os.makedirs(dataset_output_path, exist_ok=True)
#     os.makedirs(tensorboard_path, exist_ok=True)
#     print(f"* Creating dataset directory {dataset_output_path}/", flush=True)
#
#     # submit `N_JOBS` separate jobs
#     jobdir_end_idx = JOBDIR_START_IDX + N_JOBS
#     for job_idx in range(JOBDIR_START_IDX, jobdir_end_idx):
#
#         # specify and create the job subdirectory if it does not exist
#         params["job_dir"]         = f"{dataset_output_path}/job_{job_idx}/"
#         params["tensorboard_dir"] = f"{tensorboard_path}/job_{job_idx}/"
#
#         # create the directory if it does not exist already, otherwise raises an
#         # error, which is good because *might* not want to override data our
#         # existing directories!
#         os.makedirs(params["tensorboard_dir"], exist_ok=True)
#         try:
#             job_dir_exists_already = bool(
#                 JOB_TYPE in ["generate", "test"] or FORCE_OVERWRITE
#             )
#             os.makedirs(params["job_dir"], exist_ok=job_dir_exists_already)
#             print(
#                 f"* Creating model subdirectory {dataset_output_path}/job_{job_idx}/",
#                 flush=True,
#             )
#         except FileExistsError:
#             print(
#                 f"-- Model subdirectory {dataset_output_path}/job_{job_idx}/ already exists.",
#                 flush=True,
#             )
#             if not RESTART:
#                 continue
#
#         # write the `input.csv` file
#         write_input_csv(params_dict=params, filename="input.csv")
#
#         # write `submit.sh` and submit
#         if USE_SLURM:
#             print("* Writing submission script.", flush=True)
#             write_submission_script(job_dir=params["job_dir"],
#                                     job_idx=job_idx,
#                                     job_type=params["job_type"],
#                                     max_n_nodes=params["max_n_nodes"],
#                                     runtime=RUN_TIME,
#                                     mem=MEM_GB,
#                                     ptn=PARTITION,
#                                     cpu_per_task=CPUS_PER_TASK,
#                                     python_bin_path=PYTHON_PATH)
#
#             print("* Submitting job to SLURM.", flush=True)
#             subprocess.run(["sbatch", params["job_dir"] + "submit.sh"],
#                            check=True)
#         else:
#             print("* Running job as a normal process.", flush=True)
#             subprocess.run(["ls", f"{PYTHON_PATH}"], check=True)
#             subprocess.run([f"{PYTHON_PATH}",
#                             f"{GRAPHINVENT_PATH}main.py",
#                             "--job-dir",
#                             params["job_dir"]],
#                            check=True)
#
#         # sleep a few secs before submitting next job
#         print("-- Sleeping 2 seconds.")
#         time.sleep(2)
#
#
# def write_input_csv(params_dict : dict, filename : str="params.csv") -> None:
#     """
#     Writes job parameters/hyperparameters in `params_dict` to CSV using the specified
#     `filename`.
#     """
#     dict_path = params_dict["job_dir"] + filename
#
#     with open(dict_path, "w") as csv_file:
#
#         writer = csv.writer(csv_file, delimiter=";")
#         for key, value in params_dict.items():
#             writer.writerow([key, value])
#
#
# def write_submission_script(job_dir : str, job_idx : int, job_type : str, max_n_nodes : int,
#                             runtime : str, mem : int, ptn : str, cpu_per_task : int,
#                             python_bin_path : str) -> None:
#     """
#     Writes a submission script (`submit.sh`).
#
#     Args:
#     ----
#         job_dir (str)         : Job running directory.
#         job_idx (int)         : Job idx.
#         job_type (str)        : Type of job to run.
#         max_n_nodes (int)     : Maximum number of nodes in dataset.
#         runtime (str)         : Job run-time limit in hh:mm:ss format.
#         mem (int)             : Gigabytes to reserve.
#         ptn (str)             : Partition to use, either "core" (CPU) or "gpu" (GPU).
#         cpu_per_task (int)    : How many CPUs to use per task.
#         python_bin_path (str) : Path to Python binary to use.
#     """
#     submit_filename = job_dir + "submit.sh"
#     with open(submit_filename, "w") as submit_file:
#         submit_file.write("#!/bin/bash\n")
#         submit_file.write(f"#SBATCH --job-name={job_type}{max_n_nodes}_{job_idx}\n")
#         submit_file.write(f"#SBATCH --output={job_type}{max_n_nodes}_{job_idx}o\n")
#         submit_file.write(f"#SBATCH --time={runtime}\n")
#         submit_file.write(f"#SBATCH --mem={mem}g\n")
#         submit_file.write(f"#SBATCH --partition={ptn}\n")
#         submit_file.write("#SBATCH --nodes=1\n")
#         submit_file.write(f"#SBATCH --cpus-per-task={cpu_per_task}\n")
#         if ptn == "gpu":
#             submit_file.write("#SBATCH --gres=gpu:1\n")
#         submit_file.write("hostname\n")
#         submit_file.write("export QT_QPA_PLATFORM='offscreen'\n")
#         submit_file.write(f"{python_bin_path} {GRAPHINVENT_PATH}main.py --job-dir {job_dir}")
#         submit_file.write(f" > {job_dir}output.o${{SLURM_JOB_ID}}\n")
#
#
# def check_paths() -> None:
#     """
#     Checks that paths to Python binary, data, and GraphINVENT are properly
#     defined before running a job, and tells the user to define them if not.
#     """
#     for path in [PYTHON_PATH, GRAPHINVENT_PATH, DATA_PATH]:
#         if "path/to/" in path:
#             print("!!!")
#             print("* Update the following paths in `submit.py` before running:")
#             print("-- `PYTHON_PATH`\n-- `GRAPHINVENT_PATH`\n-- `DATA_PATH`")
#             sys.exit(0)
#
# submit()
# Out:
# /content/GraphINVENT
# * Creating dataset directory /root/GraphINVENT/output_gdb13_1K-debug/example-job-name/
# * Creating model subdirectory /root/GraphINVENT/output_gdb13_1K-debug/example-job-name/job_0/
# * Running job as a normal process.
# /usr/local/envs/graphinvent/bin/python3.8
# * Running job using HDF datasets located at ./data/pre-training/gdb13_1K-debug/
# * Checking that the relevant parameters match those used in preprocessing the dataset.
# -- Job parameters match preprocessing parameters.
# * Run mode: 'train'
# * Setting up training job.
# * Loading preprocessed training set.
# -- time elapsed: 0.00336 s
# * Loading preprocessed validation set.
# -- time elapsed: 0.00588 s
# * Loading training set properties.
# * Touching output files.
# * Defining model.
# -- Defining optimizer.
# -- Defining scheduler.
# * Beginning training.
# * Training epoch 1.
# * Evaluating epoch 1.
# * Training epoch 2.
# * Evaluating epoch 2.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 84 molecules in 0.1341 s
# --626.42 molecules/s
# Batch 1 of 2
# Generated 95 molecules in 1.734e+09 s
# --5.4787e-08 molecules/s
# Batch 2 of 2
# Generated 94 molecules in 0.2726 s
# --344.77 molecules/s
# * Saving model state at Epoch 2.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 3.
# * Evaluating epoch 3.
# * Training epoch 4.
# * Evaluating epoch 4.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 90 molecules in 0.1362 s
# --661.01 molecules/s
# Batch 1 of 2
# Generated 93 molecules in 1.734e+09 s
# --5.3634e-08 molecules/s
# Batch 2 of 2
# Generated 92 molecules in 0.2756 s
# --333.84 molecules/s
# * Saving model state at Epoch 4.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 5.
# * Evaluating epoch 5.
# * Training epoch 6.
# * Evaluating epoch 6.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 91 molecules in 0.1357 s
# --670.39 molecules/s
# Batch 1 of 2
# Generated 93 molecules in 1.734e+09 s
# --5.3634e-08 molecules/s
# Batch 2 of 2
# Generated 92 molecules in 0.2752 s
# --334.32 molecules/s
# * Saving model state at Epoch 6.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 7.
# * Evaluating epoch 7.
# * Training epoch 8.
# * Evaluating epoch 8.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 89 molecules in 0.1379 s
# --645.2 molecules/s
# Batch 1 of 2
# Generated 88 molecules in 1.734e+09 s
# --5.075e-08 molecules/s
# Batch 2 of 2
# Generated 89 molecules in 0.2829 s
# --314.59 molecules/s
# * Saving model state at Epoch 8.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 9.
# * Evaluating epoch 9.
# * Training epoch 10.
# * Evaluating epoch 10.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 89 molecules in 0.1362 s
# --653.52 molecules/s
# Batch 1 of 2
# Generated 89 molecules in 1.734e+09 s
# --5.1327e-08 molecules/s
# Batch 2 of 2
# Generated 87 molecules in 0.2896 s
# --300.45 molecules/s
# * Saving model state at Epoch 10.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 11.
# * Evaluating epoch 11.
# * Training epoch 12.
# * Evaluating epoch 12.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 86 molecules in 0.1337 s
# --643.46 molecules/s
# Batch 1 of 2
# Generated 87 molecules in 1.734e+09 s
# --5.0174e-08 molecules/s
# Batch 2 of 2
# Generated 85 molecules in 0.2734 s
# --310.88 molecules/s
# * Saving model state at Epoch 12.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 13.
# * Evaluating epoch 13.
# * Training epoch 14.
# * Evaluating epoch 14.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 83 molecules in 0.1374 s
# --603.91 molecules/s
# Batch 1 of 2
# Generated 74 molecules in 1.734e+09 s
# --4.2676e-08 molecules/s
# Batch 2 of 2
# Generated 78 molecules in 0.2935 s
# --265.73 molecules/s
# * Saving model state at Epoch 14.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 15.
# * Evaluating epoch 15.
# * Training epoch 16.
# * Evaluating epoch 16.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 55 molecules in 0.2009 s
# --273.82 molecules/s
# Batch 1 of 2
# Generated 55 molecules in 1.734e+09 s
# --3.1719e-08 molecules/s
# Batch 2 of 2
# Generated 52 molecules in 0.4515 s
# --115.18 molecules/s
# * Saving model state at Epoch 16.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 17.
# * Evaluating epoch 17.
# * Training epoch 18.
# * Evaluating epoch 18.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 60 molecules in 0.3819 s
# --157.09 molecules/s
# Batch 1 of 2
# Generated 54 molecules in 1.734e+09 s
# --3.1142e-08 molecules/s
# Batch 2 of 2
# Generated 51 molecules in 0.7512 s
# --67.888 molecules/s
# * Saving model state at Epoch 18.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 19.
# * Evaluating epoch 19.
# * Training epoch 20.
# * Evaluating epoch 20.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 60 molecules in 0.2854 s
# --210.2 molecules/s
# Batch 1 of 2
# Generated 58 molecules in 1.734e+09 s
# --3.3449e-08 molecules/s
# Batch 2 of 2
# Generated 64 molecules in 0.6189 s
# --103.41 molecules/s
# * Saving model state at Epoch 20.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 21.
# * Evaluating epoch 21.
# * Training epoch 22.
# * Evaluating epoch 22.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 52 molecules in 0.2934 s
# --177.23 molecules/s
# Batch 1 of 2
# Generated 55 molecules in 1.734e+09 s
# --3.1719e-08 molecules/s
# Batch 2 of 2
# Generated 56 molecules in 0.7999 s
# --70.005 molecules/s
# * Saving model state at Epoch 22.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 23.
# * Evaluating epoch 23.
# * Training epoch 24.
# * Evaluating epoch 24.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 58 molecules in 0.5598 s
# --103.61 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 1.137 s
# --43.984 molecules/s
# * Saving model state at Epoch 24.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 25.
# * Evaluating epoch 25.
# * Training epoch 26.
# * Evaluating epoch 26.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 0.5478 s
# --91.276 molecules/s
# Batch 1 of 2
# Generated 55 molecules in 1.734e+09 s
# --3.1719e-08 molecules/s
# Batch 2 of 2
# Generated 55 molecules in 1.641 s
# --33.513 molecules/s
# * Saving model state at Epoch 26.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 27.
# * Evaluating epoch 27.
# * Training epoch 28.
# * Evaluating epoch 28.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 0.77 s
# --64.937 molecules/s
# Batch 1 of 2
# Generated 53 molecules in 1.734e+09 s
# --3.0566e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 1.493 s
# --33.485 molecules/s
# * Saving model state at Epoch 28.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 29.
# * Evaluating epoch 29.
# * Training epoch 30.
# * Evaluating epoch 30.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 52 molecules in 1.144 s
# --45.452 molecules/s
# Batch 1 of 2
# Generated 52 molecules in 1.734e+09 s
# --2.9989e-08 molecules/s
# Batch 2 of 2
# Generated 57 molecules in 2.511 s
# --22.705 molecules/s
# * Saving model state at Epoch 30.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 31.
# * Evaluating epoch 31.
# * Training epoch 32.
# * Evaluating epoch 32.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 53 molecules in 2.123 s
# --24.97 molecules/s
# Batch 1 of 2
# Generated 55 molecules in 1.734e+09 s
# --3.1719e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 3.096 s
# --16.152 molecules/s
# * Saving model state at Epoch 32.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 33.
# * Evaluating epoch 33.
# * Training epoch 34.
# * Evaluating epoch 34.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 60 molecules in 1.46 s
# --41.084 molecules/s
# Batch 1 of 2
# Generated 53 molecules in 1.734e+09 s
# --3.0566e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 3.602 s
# --13.882 molecules/s
# * Saving model state at Epoch 34.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 35.
# * Evaluating epoch 35.
# * Training epoch 36.
# * Evaluating epoch 36.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 54 molecules in 1.717 s
# --31.454 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 55 molecules in 2.937 s
# --18.726 molecules/s
# * Saving model state at Epoch 36.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 37.
# * Evaluating epoch 37.
# * Training epoch 38.
# * Evaluating epoch 38.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 1.685 s
# --29.665 molecules/s
# Batch 1 of 2
# Generated 52 molecules in 1.734e+09 s
# --2.9989e-08 molecules/s
# Batch 2 of 2
# Generated 55 molecules in 3.172 s
# --17.341 molecules/s
# * Saving model state at Epoch 38.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 39.
# * Evaluating epoch 39.
# * Training epoch 40.
# * Evaluating epoch 40.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 53 molecules in 1.658 s
# --31.966 molecules/s
# Batch 1 of 2
# Generated 53 molecules in 1.734e+09 s
# --3.0566e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 3.115 s
# --17.013 molecules/s
# * Saving model state at Epoch 40.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 41.
# * Evaluating epoch 41.
# * Training epoch 42.
# * Evaluating epoch 42.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 56 molecules in 2.751 s
# --20.356 molecules/s
# Batch 1 of 2
# Generated 54 molecules in 1.734e+09 s
# --3.1142e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 4.115 s
# --12.88 molecules/s
# * Saving model state at Epoch 42.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 43.
# * Evaluating epoch 43.
# * Training epoch 44.
# * Evaluating epoch 44.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 1.855 s
# --27.497 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 3.507 s
# --15.114 molecules/s
# * Saving model state at Epoch 44.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 45.
# * Evaluating epoch 45.
# * Training epoch 46.
# * Evaluating epoch 46.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 1.669 s
# --30.55 molecules/s
# Batch 1 of 2
# Generated 54 molecules in 1.734e+09 s
# --3.1142e-08 molecules/s
# Batch 2 of 2
# Generated 51 molecules in 4.292 s
# --11.882 molecules/s
# * Saving model state at Epoch 46.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 47.
# * Evaluating epoch 47.
# * Training epoch 48.
# * Evaluating epoch 48.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 54 molecules in 1.783 s
# --30.28 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 4.305 s
# --12.543 molecules/s
# * Saving model state at Epoch 48.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 49.
# * Evaluating epoch 49.
# * Training epoch 50.
# * Evaluating epoch 50.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 52 molecules in 1.87 s
# --27.807 molecules/s
# Batch 1 of 2
# Generated 57 molecules in 1.734e+09 s
# --3.2872e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 4.497 s
# --11.119 molecules/s
# * Saving model state at Epoch 50.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 51.
# * Evaluating epoch 51.
# * Training epoch 52.
# * Evaluating epoch 52.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 53 molecules in 1.837 s
# --28.846 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 3.867 s
# --13.963 molecules/s
# * Saving model state at Epoch 52.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 53.
# * Evaluating epoch 53.
# * Training epoch 54.
# * Evaluating epoch 54.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 1.703 s
# --29.353 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 52 molecules in 3.484 s
# --14.925 molecules/s
# * Saving model state at Epoch 54.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 55.
# * Evaluating epoch 55.
# * Training epoch 56.
# * Evaluating epoch 56.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 1.908 s
# --26.727 molecules/s
# Batch 1 of 2
# Generated 54 molecules in 1.734e+09 s
# --3.1142e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 3.652 s
# --14.787 molecules/s
# * Saving model state at Epoch 56.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 57.
# * Evaluating epoch 57.
# * Training epoch 58.
# * Evaluating epoch 58.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 52 molecules in 2.487 s
# --20.908 molecules/s
# Batch 1 of 2
# Generated 52 molecules in 1.734e+09 s
# --2.9989e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 4.216 s
# --12.808 molecules/s
# * Saving model state at Epoch 58.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 59.
# * Evaluating epoch 59.
# * Training epoch 60.
# * Evaluating epoch 60.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 52 molecules in 3.113 s
# --16.707 molecules/s
# Batch 1 of 2
# Generated 53 molecules in 1.734e+09 s
# --3.0566e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 5.035 s
# --9.9304 molecules/s
# * Saving model state at Epoch 60.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 61.
# * Evaluating epoch 61.
# * Training epoch 62.
# * Evaluating epoch 62.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 52 molecules in 2.935 s
# --17.716 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 4.736 s
# --10.558 molecules/s
# * Saving model state at Epoch 62.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 63.
# * Evaluating epoch 63.
# * Training epoch 64.
# * Evaluating epoch 64.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 2.331 s
# --21.449 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 4.11 s
# --13.14 molecules/s
# * Saving model state at Epoch 64.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 65.
# * Evaluating epoch 65.
# * Training epoch 66.
# * Evaluating epoch 66.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 1.761 s
# --28.4 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 4.074 s
# --13.255 molecules/s
# * Saving model state at Epoch 66.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 67.
# * Evaluating epoch 67.
# * Training epoch 68.
# * Evaluating epoch 68.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 1.868 s
# --27.308 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 4.707 s
# --11.472 molecules/s
# * Saving model state at Epoch 68.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 69.
# * Evaluating epoch 69.
# * Training epoch 70.
# * Evaluating epoch 70.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 2.02 s
# --24.755 molecules/s
# Batch 1 of 2
# Generated 55 molecules in 1.734e+09 s
# --3.1719e-08 molecules/s
# Batch 2 of 2
# Generated 55 molecules in 4.301 s
# --12.787 molecules/s
# * Saving model state at Epoch 70.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 71.
# * Evaluating epoch 71.
# * Training epoch 72.
# * Evaluating epoch 72.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 2.437 s
# --20.52 molecules/s
# Batch 1 of 2
# Generated 52 molecules in 1.734e+09 s
# --2.9989e-08 molecules/s
# Batch 2 of 2
# Generated 51 molecules in 4.381 s
# --11.64 molecules/s
# * Saving model state at Epoch 72.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 73.
# * Evaluating epoch 73.
# * Training epoch 74.
# * Evaluating epoch 74.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 1.913 s
# --26.135 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 51 molecules in 4.406 s
# --11.576 molecules/s
# * Saving model state at Epoch 74.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 75.
# * Evaluating epoch 75.
# * Training epoch 76.
# * Evaluating epoch 76.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 53 molecules in 1.975 s
# --26.84 molecules/s
# Batch 1 of 2
# Generated 53 molecules in 1.734e+09 s
# --3.0566e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 5.046 s
# --9.9091 molecules/s
# * Saving model state at Epoch 76.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 77.
# * Evaluating epoch 77.
# * Training epoch 78.
# * Evaluating epoch 78.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 53 molecules in 1.836 s
# --28.864 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 4.615 s
# --10.834 molecules/s
# * Saving model state at Epoch 78.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 79.
# * Evaluating epoch 79.
# * Training epoch 80.
# * Evaluating epoch 80.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 2.126 s
# --23.517 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 4.713 s
# --11.245 molecules/s
# * Saving model state at Epoch 80.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 81.
# * Evaluating epoch 81.
# * Training epoch 82.
# * Evaluating epoch 82.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 54 molecules in 1.951 s
# --27.684 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 4.186 s
# --12.662 molecules/s
# * Saving model state at Epoch 82.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 83.
# * Evaluating epoch 83.
# * Training epoch 84.
# * Evaluating epoch 84.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 2.248 s
# --22.689 molecules/s
# Batch 1 of 2
# Generated 52 molecules in 1.734e+09 s
# --2.9989e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 4.168 s
# --12.715 molecules/s
# * Saving model state at Epoch 84.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 85.
# * Evaluating epoch 85.
# * Training epoch 86.
# * Evaluating epoch 86.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 2.063 s
# --24.725 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 3.871 s
# --13.69 molecules/s
# * Saving model state at Epoch 86.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 87.
# * Evaluating epoch 87.
# * Training epoch 88.
# * Evaluating epoch 88.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 55 molecules in 1.902 s
# --28.922 molecules/s
# Batch 1 of 2
# Generated 51 molecules in 1.734e+09 s
# --2.9412e-08 molecules/s
# Batch 2 of 2
# Generated 54 molecules in 3.779 s
# --14.29 molecules/s
# * Saving model state at Epoch 88.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 89.
# * Evaluating epoch 89.
# * Training epoch 90.
# * Evaluating epoch 90.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 2.428 s
# --20.595 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 4.297 s
# --11.637 molecules/s
# * Saving model state at Epoch 90.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 91.
# * Evaluating epoch 91.
# * Training epoch 92.
# * Evaluating epoch 92.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 1.948 s
# --26.184 molecules/s
# Batch 1 of 2
# Generated 53 molecules in 1.734e+09 s
# --3.0566e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 3.969 s
# --13.353 molecules/s
# * Saving model state at Epoch 92.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 93.
# * Evaluating epoch 93.
# * Training epoch 94.
# * Evaluating epoch 94.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 52 molecules in 2.424 s
# --21.452 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 51 molecules in 4.378 s
# --11.649 molecules/s
# * Saving model state at Epoch 94.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 95.
# * Evaluating epoch 95.
# * Training epoch 96.
# * Evaluating epoch 96.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 53 molecules in 2.806 s
# --18.886 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 53 molecules in 4.844 s
# --10.942 molecules/s
# * Saving model state at Epoch 96.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 97.
# * Evaluating epoch 97.
# * Training epoch 98.
# * Evaluating epoch 98.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 3.166 s
# --16.107 molecules/s
# Batch 1 of 2
# Generated 53 molecules in 1.734e+09 s
# --3.0566e-08 molecules/s
# Batch 2 of 2
# Generated 50 molecules in 5.072 s
# --9.8578 molecules/s
# * Saving model state at Epoch 98.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# * Training epoch 99.
# * Evaluating epoch 99.
# * Training epoch 100.
# * Evaluating epoch 100.
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 50 molecules in 3.141 s
# --15.918 molecules/s
# Batch 1 of 2
# Generated 50 molecules in 1.734e+09 s
# --2.8835e-08 molecules/s
# Batch 2 of 2
# Generated 51 molecules in 5.096 s
# --10.009 molecules/s
# * Saving model state at Epoch 100.
# * Evaluating model.
# -- Calculating NLL statistics for validation set.
# -- Calculating NLL statistics for training set.
# -- time elapsed: 567.41409 s
# -- Sleeping 2 seconds.
# 100%|██████████| 3/3 [00:01<00:00,  2.08it/s]
# 100%|██████████| 2/2 [00:00<00:00,  5.02it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.93it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.88it/s]
# 84it [00:00, 634.92it/s]
# 95it [00:00, 677.95it/s]
# 94it [00:00, 717.37it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.21it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.76it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# 90it [00:00, 667.09it/s]
# 93it [00:00, 675.25it/s]
# 92it [00:00, 695.47it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.69it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.66it/s]
# 91it [00:00, 677.04it/s]
# 93it [00:00, 705.34it/s]
# 92it [00:00, 695.67it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.23it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.89it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.57it/s]
# 89it [00:00, 651.71it/s]
# 88it [00:00, 605.58it/s]
# 89it [00:00, 648.39it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.92it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.49it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.44it/s]
# 89it [00:00, 660.58it/s]
# 89it [00:00, 666.39it/s]
# 87it [00:00, 595.53it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.23it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.80it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.46it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# 86it [00:00, 649.43it/s]
# 87it [00:00, 606.98it/s]
# 85it [00:00, 642.82it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.91it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.59it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.53it/s]
# 83it [00:00, 609.74it/s]
# 74it [00:00, 556.82it/s]
# 78it [00:00, 525.72it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.33it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.80it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.19it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.03it/s]
# 55it [00:00, 275.86it/s]
# 55it [00:00, 237.84it/s]
# 52it [00:00, 217.09it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.52it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.90it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.65it/s]
# 60it [00:00, 157.68it/s]
# 54it [00:00, 123.44it/s]
# 51it [00:00, 145.65it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.06it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.18it/s]
# 100%|██████████| 3/3 [00:06<00:00,  2.18s/it]
# 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# 60it [00:00, 211.11it/s]
# 58it [00:00, 185.56it/s]
# 64it [00:00, 199.81it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.65it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.66it/s]
# 52it [00:00, 177.92it/s]
# 55it [00:00, 120.80it/s]
# 56it [00:00, 114.20it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.30it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.81it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.18it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# 58it [00:00, 103.86it/s]
# 51it [00:00, 69.26it/s]
# 100%|██████████| 50/50 [00:00<00:00, 91.01it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.61it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.94it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.59it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.42it/s]
# 100%|██████████| 50/50 [00:00<00:00, 91.53it/s]
# 55it [00:01, 33.51it/s]
# 55it [00:01, 52.87it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.49it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.55it/s]
# 100%|██████████| 50/50 [00:00<00:00, 65.07it/s]
# 53it [00:00, 67.55it/s]
# 100%|██████████| 50/50 [00:00<00:00, 72.39it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.50it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.75it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.17it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.59it/s]
# 52it [00:01, 45.50it/s]
# 52it [00:00, 72.51it/s]
# 57it [00:01, 42.64it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.13it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.97it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.49it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.84it/s]
# 53it [00:02, 24.99it/s]
# 55it [00:00, 56.27it/s]
# 100%|██████████| 50/50 [00:00<00:00, 53.10it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.53it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.76it/s]
# 60it [00:01, 41.12it/s]
# 53it [00:01, 31.15it/s]
# 100%|██████████| 50/50 [00:02<00:00, 23.91it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.08it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.71it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.23it/s]
# 54it [00:01, 31.48it/s]
# 100%|██████████| 50/50 [00:00<00:00, 50.32it/s]
# 55it [00:01, 46.32it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.15it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.83it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# 100%|██████████| 50/50 [00:01<00:00, 29.69it/s]
# 52it [00:01, 47.86it/s]
# 55it [00:01, 37.83it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.27it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.16it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.03it/s]
# 53it [00:01, 31.99it/s]
# 53it [00:01, 39.60it/s]
# 53it [00:01, 37.33it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.41it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.97it/s]
# 56it [00:02, 20.37it/s]
# 54it [00:01, 34.21it/s]
# 53it [00:01, 39.95it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.90it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.28it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.11it/s]
# 51it [00:01, 27.51it/s]
# 51it [00:02, 20.17it/s]
# 53it [00:01, 33.27it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.73it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.39it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.46it/s]
# 51it [00:01, 30.57it/s]
# 54it [00:02, 26.10it/s]
# 51it [00:02, 19.91it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.48it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.41it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.33it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.63it/s]
# 54it [00:01, 30.30it/s]
# 51it [00:02, 22.79it/s]
# 54it [00:02, 21.97it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.49it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.56it/s]
# 52it [00:01, 27.83it/s]
# 57it [00:01, 29.43it/s]
# 100%|██████████| 50/50 [00:02<00:00, 19.33it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.60it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.64it/s]
# 53it [00:01, 28.87it/s]
# 100%|██████████| 50/50 [00:01<00:00, 28.95it/s]
# 54it [00:01, 27.11it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.17it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.80it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.74it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# 100%|██████████| 50/50 [00:01<00:00, 29.38it/s]
# 100%|██████████| 50/50 [00:01<00:00, 29.93it/s]
# 52it [00:01, 29.85it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.37it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.77it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.13it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.82it/s]
# 51it [00:01, 26.75it/s]
# 54it [00:01, 32.79it/s]
# 54it [00:01, 31.56it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.67it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.05it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.32it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.82it/s]
# 52it [00:02, 20.92it/s]
# 52it [00:01, 29.13it/s]
# 54it [00:01, 31.93it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.74it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.41it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.82it/s]
# 52it [00:03, 16.71it/s]
# 53it [00:01, 28.23it/s]
# 100%|██████████| 50/50 [00:01<00:00, 26.68it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.74it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.54it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.47it/s]
# 52it [00:02, 17.72it/s]
# 100%|██████████| 50/50 [00:01<00:00, 26.35it/s]
# 100%|██████████| 50/50 [00:01<00:00, 28.37it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.67it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# 100%|██████████| 50/50 [00:02<00:00, 21.47it/s]
# 51it [00:02, 19.39it/s]
# 54it [00:01, 31.11it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.65it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# 100%|██████████| 50/50 [00:01<00:00, 28.42it/s]
# 51it [00:03, 16.95it/s]
# 54it [00:02, 24.02it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.48it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.58it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.57it/s]
# 51it [00:01, 27.33it/s]
# 51it [00:02, 20.49it/s]
# 54it [00:02, 19.41it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.01it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.53it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.43it/s]
# 100%|██████████| 50/50 [00:02<00:00, 24.77it/s]
# 55it [00:03, 18.25it/s]
# 55it [00:02, 24.81it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.54it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.28it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.70it/s]
# 100%|██████████| 50/50 [00:02<00:00, 20.53it/s]
# 52it [00:03, 16.89it/s]
# 51it [00:01, 27.02it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.53it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.25it/s]
# 100%|██████████| 50/50 [00:01<00:00, 26.16it/s]
# 51it [00:02, 18.71it/s]
# 51it [00:02, 21.05it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.56it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.63it/s]
# 53it [00:01, 26.86it/s]
# 53it [00:02, 23.71it/s]
# 100%|██████████| 50/50 [00:03<00:00, 16.59it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.30it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.45it/s]
# 53it [00:01, 28.89it/s]
# 51it [00:01, 26.39it/s]
# 100%|██████████| 50/50 [00:02<00:00, 18.26it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.58it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.56it/s]
# 100%|██████████| 50/50 [00:02<00:00, 23.53it/s]
# 51it [00:01, 28.81it/s]
# 53it [00:02, 20.80it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.53it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.39it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.47it/s]
# 54it [00:01, 27.71it/s]
# 51it [00:01, 26.40it/s]
# 53it [00:02, 24.18it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.10it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.79it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.73it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.50it/s]
# 51it [00:02, 22.70it/s]
# 52it [00:01, 28.94it/s]
# 53it [00:01, 28.25it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.18it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.67it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.83it/s]
# 51it [00:02, 24.74it/s]
# 100%|██████████| 50/50 [00:01<00:00, 25.91it/s]
# 53it [00:01, 30.01it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.35it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.91it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.13it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.86it/s]
# 55it [00:01, 28.94it/s]
# 51it [00:01, 26.81it/s]
# 54it [00:01, 29.37it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.79it/s]
# 100%|██████████| 50/50 [00:02<00:00, 20.61it/s]
# 100%|██████████| 50/50 [00:01<00:00, 28.01it/s]
# 100%|██████████| 50/50 [00:01<00:00, 27.38it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.40it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.38it/s]
# 100%|██████████| 3/3 [00:03<00:00,  1.09s/it]
# 100%|██████████| 2/2 [00:00<00:00,  3.02it/s]
# 51it [00:01, 26.20it/s]
# 53it [00:01, 27.19it/s]
# 53it [00:01, 26.76it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.57it/s]
# 100%|██████████| 3/3 [00:02<00:00,  1.21it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.83it/s]
# 52it [00:02, 21.47it/s]
# 100%|██████████| 50/50 [00:01<00:00, 26.12it/s]
# 51it [00:01, 26.66it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.36it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.54it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.83it/s]
# 53it [00:02, 18.90it/s]
# 100%|██████████| 50/50 [00:01<00:00, 25.50it/s]
# 53it [00:01, 26.55it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.39it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.19it/s]
# 51it [00:03, 16.11it/s]
# 53it [00:01, 26.94it/s]
# 100%|██████████| 50/50 [00:01<00:00, 26.82it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.56it/s]
# 100%|██████████| 3/3 [00:01<00:00,  1.62it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.57it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.93it/s]
# 100%|██████████| 50/50 [00:01<00:00, 25.99it/s]
# 51it [00:01, 26.64it/s]

# %% [markdown]
# # Generating New Molecules from the Trained Model

# %%
# %%bash
# pwd
# source activate graphinvent
#
# python3.8
# # load general packages and functions
# import csv
# import sys
# import os
# from pathlib import Path
# import subprocess
# import time
# import torch
# import matplotlib.pyplot as plt
#
#
# # define what you want to do for the specified job(s)
# DATASET          = "gdb13_1K-debug"    # dataset name in "./data/pre-training/"
# JOB_TYPE         = "generate"          # "preprocess", "train", "generate", or "test"
# JOBDIR_START_IDX = 0                   # where to start indexing job dirs
# N_JOBS           = 1                   # number of jobs to run per model
# RESTART          = False               # whether or not this is a restart job
# FORCE_OVERWRITE  = True                # overwrite job directories which already exist
# JOBNAME          = "example-job-name"  # used to create a sub directory
#
# # if running using SLURM sbatch, specify params below
# USE_SLURM = False                        # use SLURM or not
# RUN_TIME  = "1-00:00:00"                 # hh:mm:ss
# MEM_GB    = 20                           # required RAM in GB
#
# # for SLURM jobs, set partition to run job on (preprocessing jobs run entirely on
# # CPU, so no need to request GPU partition; all other job types benefit from running
# # on a GPU)
# if JOB_TYPE == "preprocess":
#     PARTITION     = "core"
#     CPUS_PER_TASK = 1
# else:
#     PARTITION     = "gpu"
#     CPUS_PER_TASK = 4
#
# # set paths here
# HOME             = str(Path.home())
# PYTHON_PATH      = "/usr/local/envs/graphinvent/bin/python3.8"
# GRAPHINVENT_PATH = "./graphinvent/"
# DATA_PATH        = "./data/pre-training/"
#
# if torch.cuda.is_available():
#     DEVICE = "cuda"
# else:
#     DEVICE = "cpu"
#
# # define dataset-specific parameters
# params = {
#     "atom_types"   : ["C", "N", "O", "S", "Cl"],
#     "formal_charge": [-1, 0, +1],
#     "max_n_nodes"  : 13,
#     "job_type"     : JOB_TYPE,
#     "dataset_dir"  : f"{DATA_PATH}{DATASET}/",
#     "restart"      : RESTART,
#     "model"        : "GGNN",
#     "sample_every" : 2,
#     "init_lr"      : 1e-4,
#     "epochs"       : 100,
#     "batch_size"   : 50,
#     "block_size"   : 1000,
#     "device"       : DEVICE,
#     "n_samples"    : 100,
#     # additional paramaters can be defined here, if different from the "defaults"
#     # for instance, for "generate" jobs, don't forget to specify "generation_epoch"
#     # and "n_samples"
# }
#
#
# def submit() -> None:
#     """
#     Creates and submits submission script. Uses global variables defined at top
#     of this file.
#     """
#     check_paths()
#
#     # create an output directory
#     dataset_output_path = f"{HOME}/GraphINVENT/output_{DATASET}"
#     tensorboard_path    = os.path.join(dataset_output_path, "tensorboard")
#     if JOBNAME != "":
#         dataset_output_path = os.path.join(dataset_output_path, JOBNAME)
#         tensorboard_path    = os.path.join(tensorboard_path, JOBNAME)
#
#     os.makedirs(dataset_output_path, exist_ok=True)
#     os.makedirs(tensorboard_path, exist_ok=True)
#     print(f"* Creating dataset directory {dataset_output_path}/", flush=True)
#
#     # submit `N_JOBS` separate jobs
#     jobdir_end_idx = JOBDIR_START_IDX + N_JOBS
#     for job_idx in range(JOBDIR_START_IDX, jobdir_end_idx):
#
#         # specify and create the job subdirectory if it does not exist
#         params["job_dir"]         = f"{dataset_output_path}/job_{job_idx}/"
#         params["tensorboard_dir"] = f"{tensorboard_path}/job_{job_idx}/"
#
#         # create the directory if it does not exist already, otherwise raises an
#         # error, which is good because *might* not want to override data our
#         # existing directories!
#         os.makedirs(params["tensorboard_dir"], exist_ok=True)
#         try:
#             job_dir_exists_already = bool(
#                 JOB_TYPE in ["generate", "test"] or FORCE_OVERWRITE
#             )
#             os.makedirs(params["job_dir"], exist_ok=job_dir_exists_already)
#             print(
#                 f"* Creating model subdirectory {dataset_output_path}/job_{job_idx}/",
#                 flush=True,
#             )
#         except FileExistsError:
#             print(
#                 f"-- Model subdirectory {dataset_output_path}/job_{job_idx}/ already exists.",
#                 flush=True,
#             )
#             if not RESTART:
#                 continue
#
#         # write the `input.csv` file
#         write_input_csv(params_dict=params, filename="input.csv")
#
#         # write `submit.sh` and submit
#         if USE_SLURM:
#             print("* Writing submission script.", flush=True)
#             write_submission_script(job_dir=params["job_dir"],
#                                     job_idx=job_idx,
#                                     job_type=params["job_type"],
#                                     max_n_nodes=params["max_n_nodes"],
#                                     runtime=RUN_TIME,
#                                     mem=MEM_GB,
#                                     ptn=PARTITION,
#                                     cpu_per_task=CPUS_PER_TASK,
#                                     python_bin_path=PYTHON_PATH)
#
#             print("* Submitting job to SLURM.", flush=True)
#             subprocess.run(["sbatch", params["job_dir"] + "submit.sh"],
#                            check=True)
#         else:
#             print("* Running job as a normal process.", flush=True)
#             subprocess.run(["ls", f"{PYTHON_PATH}"], check=True)
#             subprocess.run([f"{PYTHON_PATH}",
#                             f"{GRAPHINVENT_PATH}main.py",
#                             "--job-dir",
#                             params["job_dir"]],
#                            check=True)
#
#         # sleep a few secs before submitting next job
#         print("-- Sleeping 2 seconds.")
#         time.sleep(2)
#
#
# def write_input_csv(params_dict : dict, filename : str="params.csv") -> None:
#     """
#     Writes job parameters/hyperparameters in `params_dict` to CSV using the specified
#     `filename`.
#     """
#     dict_path = params_dict["job_dir"] + filename
#
#     with open(dict_path, "w") as csv_file:
#
#         writer = csv.writer(csv_file, delimiter=";")
#         for key, value in params_dict.items():
#             writer.writerow([key, value])
#
#
# def write_submission_script(job_dir : str, job_idx : int, job_type : str, max_n_nodes : int,
#                             runtime : str, mem : int, ptn : str, cpu_per_task : int,
#                             python_bin_path : str) -> None:
#     """
#     Writes a submission script (`submit.sh`).
#
#     Args:
#     ----
#         job_dir (str)         : Job running directory.
#         job_idx (int)         : Job idx.
#         job_type (str)        : Type of job to run.
#         max_n_nodes (int)     : Maximum number of nodes in dataset.
#         runtime (str)         : Job run-time limit in hh:mm:ss format.
#         mem (int)             : Gigabytes to reserve.
#         ptn (str)             : Partition to use, either "core" (CPU) or "gpu" (GPU).
#         cpu_per_task (int)    : How many CPUs to use per task.
#         python_bin_path (str) : Path to Python binary to use.
#     """
#     submit_filename = job_dir + "submit.sh"
#     with open(submit_filename, "w") as submit_file:
#         submit_file.write("#!/bin/bash\n")
#         submit_file.write(f"#SBATCH --job-name={job_type}{max_n_nodes}_{job_idx}\n")
#         submit_file.write(f"#SBATCH --output={job_type}{max_n_nodes}_{job_idx}o\n")
#         submit_file.write(f"#SBATCH --time={runtime}\n")
#         submit_file.write(f"#SBATCH --mem={mem}g\n")
#         submit_file.write(f"#SBATCH --partition={ptn}\n")
#         submit_file.write("#SBATCH --nodes=1\n")
#         submit_file.write(f"#SBATCH --cpus-per-task={cpu_per_task}\n")
#         if ptn == "gpu":
#             submit_file.write("#SBATCH --gres=gpu:1\n")
#         submit_file.write("hostname\n")
#         submit_file.write("export QT_QPA_PLATFORM='offscreen'\n")
#         submit_file.write(f"{python_bin_path} {GRAPHINVENT_PATH}main.py --job-dir {job_dir}")
#         submit_file.write(f" > {job_dir}output.o${{SLURM_JOB_ID}}\n")
#
#
# def check_paths() -> None:
#     """
#     Checks that paths to Python binary, data, and GraphINVENT are properly
#     defined before running a job, and tells the user to define them if not.
#     """
#     for path in [PYTHON_PATH, GRAPHINVENT_PATH, DATA_PATH]:
#         if "path/to/" in path:
#             print("!!!")
#             print("* Update the following paths in `submit.py` before running:")
#             print("-- `PYTHON_PATH`\n-- `GRAPHINVENT_PATH`\n-- `DATA_PATH`")
#             sys.exit(0)
#
# submit()
# Out:
# /content/GraphINVENT
# * Creating dataset directory /root/GraphINVENT/output_gdb13_1K-debug/example-job-name/
# * Creating model subdirectory /root/GraphINVENT/output_gdb13_1K-debug/example-job-name/job_0/
# * Running job as a normal process.
# /usr/local/envs/graphinvent/bin/python3.8
# * Running job using HDF datasets located at ./data/pre-training/gdb13_1K-debug/
# * Checking that the relevant parameters match those used in preprocessing the dataset.
# -- Job parameters match preprocessing parameters.
# * Run mode: 'generate'
# * Setting up generation job.
# * Loading training set properties.
# * Loading model from saved state (Epoch 30).
# * Generating 100 molecules.
# Batch 0 of 2
# Generated 51 molecules in 1.688 s
# --30.215 molecules/s
# Batch 1 of 2
# Generated 57 molecules in 1.734e+09 s
# --3.2872e-08 molecules/s
# Batch 2 of 2
# Generated 55 molecules in 2.723 s
# --20.197 molecules/s
# -- time elapsed: 4.58171 s
# -- Sleeping 2 seconds.
# 51it [00:01, 30.26it/s]
# 57it [00:00, 64.21it/s]
# 55it [00:01, 54.86it/s]

# %% [markdown]
# # Post Processing

# %%
! for i in epochGEN{generation_epoch}_*.smi; do cat $i >> epochGEN{generation_epoch}.smi; done
# Out:
# cat: 'epochGEN{generation_epoch}_*.smi': No such file or directory

# %%
# !ls
# Out:
# cover-image.png			GNN.ipynb    README.md				tools
# data				graphinvent  submit-fine-tuning.py		tutorials
# environments			LICENSE      submit-pre-training.py
# epochGEN{generation_epoch}.smi	output	     submit-pre-training-supercloud.py

# %% [markdown]
# ## Filtering out invalid entries
# By default, GraphINVENT writes a "Xe" placeholder when an invalid molecular graph is generated, as an invalid molecular graph cannot be converted to a SMILES string for saving. The placeholder is used because the NLL is written for all generated graphs in a separate file, where the same line number in the *.nll file corresponds to the same line number in the *.smi file. Similarly, if an empty graph samples an invalid action as the first action, then no SMILES can be generated for an empty graph, so the corresponding line for an empty graph in a SMILES file contains only the "ID" of the molecule.
#
# For visualization, you might be interested in viewing only the valid molecular graphs. The SMILES for the generated molecules can thus be post-processed as follows to remove empty and invalid entries from a file before visualization:

# %%
! sed -i "/Xe/d" /root/GraphINVENT/output_gdb13_1K-debug/example-job-name/job_0/generation/epoch_2.smi          # remove "Xe" placeholders from file
! sed -i "/^ [0-9]\+$/d" /root/GraphINVENT/output_gdb13_1K-debug/example-job-name/job_0/generation/epoch_2.smi  # remove empty graphs from file

# %%
#smi_file = "/root/GraphINVENT/output_gdb13_1K-debug/example-job-name/job_0/generation/epoch_2.smi"
from google.colab import files
files.download("/root/GraphINVENT/output_gdb13_1K-debug/example-job-name/job_0/generation/epoch_2.smi")

# %% [markdown]
# # Visualizing Molecules
#
# So we generated some molecules using GraphINVENT, and will certainly want to explore them visually. Below we provide some examples using RDKit for visualizing the molecules in simple but elegant grids.
#
# ## Drawing a grid of molecules

# %% [markdown]
# ### What if thousands of molecules are generated ?
#
# Assuming you use the trained models to generate thousands (if not more) molecules, you probably don't want to visualize all of them in one massive grid. A more reasonable thing to do is to randomly sample a small subset for visualization.
#
# An example script for drawing 100 randomly selected molecules is shown below:
